# %% [markdown]
# <a href="https://colab.research.google.com/github/Prateek-Datascientist/16th-Jan-2024/blob/main/1_Feb_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/bigmart.csv')
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# Filling up na values of Item_Weight

# %%
df['Item_Weight'].isna().sum()*100/len(df)
# Out:
# 17.165317376510618

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df3
# Out:
# Series([], Name: Item_Weight, dtype: float64)

# %%
df1 = df.filter(['Item_Weight' , 'Item_Outlet_Sales'])
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_MMS = MinMaxScaler().fit_transform(df1)
print(df_MMS)
print(type(df_MMS))
# Out:
# [[0.28252456 0.28358666]
#  [0.08127419 0.03141895]
#  [0.77076511 0.15811486]
#  ...
#  [0.35992855 0.08885035]
#  [0.15808276 0.13883505]
#  [0.61000298 0.05610527]]
# <class 'numpy.ndarray'>

# %%
df_n = pd.DataFrame(df_MMS , columns = ['Item_Weight' , 'Item_Outlet_Sales'])

# %%
df_n.describe()
# Out:
#        Item_Weight  Item_Outlet_Sales
# count  7060.000000        8523.000000
# mean      0.494352           0.164551
# std       0.276479           0.130729
# min       0.000000           0.000000
# 25%       0.251191           0.061359
# 50%       0.479012           0.134908
# 75%       0.732063           0.235030
# max       1.000000           1.000000

# %%
df_n['SNo'] = np.arange(len(df))
df['SNo'] = np.arange((len(df)))
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0           FDA15          Low Fat         0.016047        Dairy  249.8092
# 1           DRC01          Regular         0.019278  Soft Drinks   48.2692
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
# 1            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  SNo
# 0               Tier 1  Supermarket Type1    0
# 1               Tier 3  Supermarket Type2    1

# %%
df_f = pd.merge(df , df_n , how = 'inner' , on = 'SNo')
df_f
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8518           FDF22          Low Fat         0.056783            Snack Foods
# 8519           FDS36          Regular         0.046982           Baking Goods
# 8520           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8521           FDN46          Regular         0.145221            Snack Foods
# 8522           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df4 = df1.copy()
# Out:
#       Item_Weight  Item_Outlet_Sales
# 0           9.300          3735.1380
# 1           5.920           443.4228
# 2          17.500          2097.2700
# 3          19.200           732.3800
# 4           8.930           994.7052
# ...           ...                ...
# 8518        6.865          2778.3834
# 8519        8.380           549.2850
# 8520       10.600          1193.1136
# 8521        7.210          1845.5976
# 8522       14.800           765.6700
#
# [8523 rows x 2 columns]

# %% [markdown]
# Standardization of Data

# %%
df5 = pd.read_csv('/content/bigmart.csv')
df6 =df5.copy()
df1.head(2)    # df1 has our filtered rows
# Out:
#    Item_Weight  Item_Outlet_Sales
# 0         9.30          3735.1380
# 1         5.92           443.4228

# %%
std_arr = StandardScaler().fit_transform(df1)
df_std = pd.DataFrame(std_arr , columns = ['Item_Weight' , 'Item_Outlet_Sales'])
df_std
# Out:
#       Item_Weight  Item_Outlet_Sales
# 0       -0.766217           0.910601
# 1       -1.494175          -1.018440
# 2        0.999834          -0.049238
# 3        1.365966          -0.849103
# 4       -0.845905          -0.695373
# ...           ...                ...
# 8518    -1.290648           0.349915
# 8519    -0.964360          -0.956402
# 8520    -0.486234          -0.579100
# 8521    -1.216345          -0.196725
# 8522     0.418329          -0.829594
#
# [8523 rows x 2 columns]

# %%
df6['Item_Outlet_Sales'].describe()  #Original Dataset
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %%
df_n['Item_Outlet_Sales'].describe()  #Normalised Dataset
# Out:
# count    8523.000000
# mean        0.164551
# std         0.130729
# min         0.000000
# 25%         0.061359
# 50%         0.134908
# 75%         0.235030
# max         1.000000
# Name: Item_Outlet_Sales, dtype: float64

# %%
df_std['Item_Outlet_Sales'].describe()    #Standardized dataset
# Out:
# count    8.523000e+03
# mean     1.638175e-16
# std      1.000059e+00
# min     -1.258790e+00
# 25%     -7.894057e-01
# 50%     -2.267687e-01
# 75%      5.391513e-01
# max      6.391045e+00
# Name: Item_Outlet_Sales, dtype: float64

# %%
sns.kdeplot(df_n['Item_Outlet_Sales'])
plt.show()
sns.kdeplot(df_std['Item_Outlet_Sales'])
plt.show()
sns.kdeplot(df6['Item_Outlet_Sales'])
# Out:
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
df6.head(2)
# Out:
# 1463
