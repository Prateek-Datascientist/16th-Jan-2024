# %% [markdown]
# <a href="https://colab.research.google.com/github/Prateek-Datascientist/16th-Jan-2024/blob/main/31_Jan_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('/bigmart.csv')
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
items = df.filter( like = 'Item' , axis = 1)
items['SNo'] = np.arange(len(items))

outlet = df.filter( like = 'Outlet' , axis = 1)
outlet['SNo'] = np.arange(len(items))
del outlet['Item_Outlet_Sales']
items
# Out:
# <ipython-input-16-7d0636225641>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items['SNo'] = np.arange(len(items))
# <ipython-input-16-7d0636225641>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlet['SNo'] = np.arange(len(items))
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# ...

# %% [markdown]
# Now we'll merge outlet and item dataframes

# %%
a = pd.merge( left = items, right = outlet, how = 'left' , on = 'SNo' )
del a['SNo']
a
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP  Item_Outlet_Sales Outlet_Identifier  \
# ...

# %%
items1 = items.head(5)
a = pd.merge( left = items1, right = outlet, how = 'right' , on = 'SNo' )
a
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 1              DRC01         5.92          Regular         0.019278
# 2              FDN15        17.50          Low Fat         0.016760
# 3              FDX07        19.20          Regular         0.000000
# 4              NCD19         8.93          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518             NaN          NaN              NaN              NaN
# 8519             NaN          NaN              NaN              NaN
# 8520             NaN          NaN              NaN              NaN
# 8521             NaN          NaN              NaN              NaN
# 8522             NaN          NaN              NaN              NaN
#
#                   Item_Type  Item_MRP  Item_Outlet_Sales   SNo  \
# 0                     Dairy  249.8092          3735.1380     0
# ...

# %%
df[df['Item_Outlet_Sales'] > 3000 ]
a = df['Item_Outlet_Sales'] > 3000
#print(type(a))
a = df['Item_Outlet_Sales']
a = df.filter(items = [0,1,2], axis = 1)
print(type(a))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.loc[df['Item_Outlet_Sales'] > 3000 ]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 7              FDP10          NaN          Low Fat         0.127470
# 9              FDU28        19.20          Regular         0.094450
# 20             FDN22        18.85          Regular         0.138190
# 21             FDW12          NaN          Regular         0.035400
# ...              ...          ...              ...              ...
# 8504           NCN18          NaN          Low Fat         0.124111
# 8506           DRF37        17.25          Low Fat         0.084676
# 8510           FDN58        13.80          Regular         0.056862
# 8511           FDF05        17.50          Low Fat         0.026980
# 8517           FDF53        20.75              reg         0.083607
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0            Dairy  249.8092            OUT049                       1999
# ...

# %%
airline = {
    "Carrier": ["B6", "WW", "B6", "B6", "WN", "WW", "B6"],
    "Origin": ["BLR", "JAI", "SAG", "SXR", "BLR", "JLR", "DLI"],
    "Destination": ["DEL", "DEL", "HYD", "DEL", "JAI", "KLH", "RPR"],
    "Time": [3, 2, 5, 3, 6, 4, 3]
}

df4 = pd.DataFrame(airline)
df5 = df4[((df4['Origin'] == 'BLR') | (df4['Destination'] == 'DEL')) & (df4['Time'] < 5 ) & (df4['Carrier'] == 'B6') ]
print(df5['Time'].sum())
# Out:
# 6

# %% [markdown]
# For the big mart dataset, you have been given a task to find the average of the MRP for the "Dairy" products which are present in the "Medium" size outlets.
#
# Expected Output
#
# Print the average MRP for Diary products in the medium size outlets rounded to 2 decimal places.

# %%
df = pd.read_csv('/content/bigmart.csv')
df.head()
df1 = df[(df['Item_Type'] == 'Dairy') & (df['Outlet_Size'] == 'Medium')]
df1['Item_MRP'].mean()
# Out:
# 148.5121743119266

# %%
data = {'col': ['A', 'B', 'A', 'B', 'A'],
        'col1': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)

result = df.groupby('col').agg({'col1': ['sum', 'mean', 'std']})

print(result.shape)
print(type(result))
print(result.columns)
print(result)
# Out:
# (2, 3)
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex([('col1',  'sum'),
#             ('col1', 'mean'),
#             ('col1',  'std')],
#            )
#     col1
#      sum mean       std
# col
# A      9  3.0  2.000000
# B      6  3.0  1.414214

# %%
df = pd.read_csv('/bigmart.csv')
df.describe(include = 'all')
a = df.groupby('Outlet_Type').agg({ 'Outlet_Size' : 'count'})
a
# Out:
#                    Outlet_Size
# Outlet_Type
# Grocery Store              528
# Supermarket Type1         3722
# Supermarket Type2          928
# Supermarket Type3          935

# %%
a = df.groupby('Outlet_Type').size()
a
# Out:
# Outlet_Type
# Grocery Store        1083
# Supermarket Type1    5577
# Supermarket Type2     928
# Supermarket Type3     935
# dtype: int64
