# %%
import numpy as np
from sklearn import datasets

iris = datasets.load_iris()
x = iris.data
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, accuracy_score

k_means = KMeans(n_clusters= 3, max_iter = 300, n_init =10 )
k_means.fit(x)
ans = k_means.labels_
target = iris.target
ypred1 = k_means.predict(x)

from sklearn.metrics import accuracy_score

score2 = accuracy_score(target,ypred1)
print(score2)

import matplotlib.pyplot as plt

plt.scatter( x[: , 0] , x[:,1], c = k_means.labels_)
# Out:
# 0.24

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate synthetic data with 4 clusters
X, Y = make_blobs(n_samples=1500, centers=5, n_features=2, random_state=42)

# Plot the generated data
plt.scatter(X[:, 0], X[:, 1], s=30, edgecolors='k', c= Y, marker= '^')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Generated Data with 4 Clusters')
plt.show()
print(X)
print(Y)
print(len(X))
print(len(Y))
# Out:
# [[ 4.9425143   1.21889383]
#  [ 2.5041663   4.70871635]
#  [-8.21612061  6.1846898 ]
#  ...
#  [ 4.9069291   2.86280048]
#  [ 1.60610583  3.03138222]
#  [-7.24494874 -6.69542929]]
# [1 4 3 ... 1 4 2]
# 1500
# 1500

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

x,y = make_blobs(n_samples  = 1000, n_features= 2, random_state= 0)
xtrain = x[ : 750]
xtest = x[750: ]
ytest = y[750: ]
# Silhoutte score is our aim
x_graph = []
y_graph = []
for k in range(2,7):
  kmeans = KMeans(n_clusters= k, random_state= 0)
  kmeans.fit(xtrain)
  labels = kmeans.predict(xtest)
  s_score = silhouette_score(xtest, labels)
  y_graph.append(s_score)
  x_graph.append(k)
  print("Silhoutte score for k=" , k, " is " , s_score)

plt.plot(x_graph,y_graph)
plt.xlabel("Value of K")
plt.ylabel("Silhoutte Score")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np

# Generate sample data
X, _ = make_blobs(n_samples=1000, centers=4, n_features=2, random_state=42)

# Define the range of clusters you want to compare
min_clusters = 2
max_clusters = 10

# Initialize variables to store silhouette scores
best_score = -1
best_n_clusters = -1

# Loop through different numbers of clusters
for n_clusters in range(min_clusters, max_clusters + 1):
    # Fit KMeans clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(X)

    # Calculate silhouette score
    silhouette_avg = silhouette_score(X, labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Update best score and number of clusters if necessary
    if silhouette_avg > best_score:
        best_score = silhouette_avg
        best_n_clusters = n_clusters

print("Best silhouette score:", best_score, "achieved with", best_n_clusters, "clusters.")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For n_clusters = 2 The average silhouette_score is : 0.5895787972208197
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For n_clusters = 3 The average silhouette_score is : 0.7521964163365819
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For n_clusters = 4 The average silhouette_score is : 0.7915983870089952
# ...

# %%
import numpy as np

data = [i for i in range(20)]
s1 = 3
s2 = 9
mean1 = s1
mean2 = s2

dist = 0

c1 = np.array([])
c2 = np.array([])

for i in data:

  if mean1 - i <= mean2 - i:
    c1 += i
  else:  c2 += i

mean1 = c1.mean()
mean2  = c2.mean()

if  mean1 < c1:
  c1 = mean1
if mena2
# Out:
# <ipython-input-6-68fd482b8a33>:20: RuntimeWarning: Mean of empty slice.
#   mean1 = c1.mean()
# <ipython-input-6-68fd482b8a33>:21: RuntimeWarning: Mean of empty slice.
#   mean2  = c2.mean()
