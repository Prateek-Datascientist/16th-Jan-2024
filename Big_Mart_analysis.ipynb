# %% [markdown]
# <a href="https://colab.research.google.com/github/Prateek-Datascientist/16th-Jan-2024/blob/main/Big_Mart_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df  = pd.read_csv("/content/bigmart.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
a = df[df.Outlet_Identifier.isin(['OUT010' , 'OUT019'])]
# Out:
# 0

# %%
df.head(-2)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
plt.figure(figsize = (20,10))

sns.boxplot( data = df, x = 'Item_Type' , y = 'Item_Outlet_Sales' )
# Out:
# <Axes: xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (20,10))

sns.barplot( data = df, x = 'Outlet_Type' , y = 'Item_Outlet_Sales' )
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.pairplot( data = df , y_vars = 'Item_Outlet_Sales' , x_vars=['Item_Weight', 'Item_Visibility', 'Item_MRP'] )

# %%
plt.figure(figsize = (30,10))
sns.boxplot(data = df , y= 'Item_Outlet_Sales' , x='Item_Type')
# Out:
# <Axes: xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.barplot(data =df , x = 'Outlet_Size' , y = 'Item_Outlet_Sales')
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
max_sales = df.Item_Outlet_Sales.max()
item = df.Item_Type[df.Item_Outlet_Sales == max_sales]
item
# Out:
# 7188    Household
# Name: Item_Type, dtype: object

# %% [markdown]
# Plot the distribution graph for the “Item_Visibility” column and find out if the majority of the values are less than the mean or greater

# %%
sns.displot( data = df , x = 'Item_Visibility')

# %% [markdown]
# Plot a graph using the x-axis as "OutletEstablishmentYear" and the y-axis as "ItemOutletSales". After plotting the graph, observe the values and determine if the old outlets are more profitable than the new ones.
#
# Note: Here, old means stores opened before the year 2000.

# %%
sns.barplot( data = df , x = 'Outlet_Establishment_Year' , y = 'Item_Outlet_Sales')
# Out:
# <Axes: xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
df.Outlet_Type.value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64
