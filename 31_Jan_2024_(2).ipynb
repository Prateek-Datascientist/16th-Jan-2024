# %% [markdown]
# <a href="https://colab.research.google.com/github/Prateek-Datascientist/16th-Jan-2024/blob/main/31_Jan_2024_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/bigmart.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# For the big mart dataset, your manager wants to make a decision on opening a new outlet, she gave you the task to provide her with the data grouped by the location of the previously opened outlets and the type of outlet and find out the average itemoutletsales for each of these groups.

# %%
df1 = df.groupby(by = ['Outlet_Location_Type' , 'Outlet_Type']).agg({'Item_Outlet_Sales' : 'mean'})
df1
# Out:
#                                         Item_Outlet_Sales
# Outlet_Location_Type Outlet_Type
# Tier 1               Grocery Store             340.329723
#                      Supermarket Type1        2313.099451
# Tier 2               Supermarket Type1        2323.990559
# Tier 3               Grocery Store             339.351662
#                      Supermarket Type1        2298.995256
#                      Supermarket Type2        1995.498739
#                      Supermarket Type3        3694.038558

# %%
print(int(df1['Item_Outlet_Sales'].max()))
# Out:
# 3694

# %%
a = df.loc[ (df['Outlet_Size'] == 'Small') & (df['Outlet_Location_Type'] == "Tier 1") ]
print(a)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 11             FDA03        18.50          Regular         0.045464
# 13             FDS46        17.60          Regular         0.047257
# 15             FDP49         9.00          Regular         0.069089
# 23             FDC37          NaN          Low Fat         0.057557
# 24             FDR28        13.85          Regular         0.025896
# ...              ...          ...              ...              ...
# 8480           FDQ58          NaN          Low Fat         0.000000
# 8490           FDU44          NaN          Regular         0.102296
# 8492           FDT34         9.30          Low Fat         0.174350
# 8517           FDF53        20.75              reg         0.083607
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 11                    Dairy  144.1102            OUT046
# ...

# %%
a1 = a.groupby( by = ['Outlet_Identifier' , 'Outlet_Location_Type' , 'Outlet_Size']).agg({'Item_Outlet_Sales': 'sum' })

print(int(a1['Item_Outlet_Sales'].max() ))
# Out:
# 2118395

# %%
a = [[1,2,3,4] , [1,2,3,4] ]

#a1 = np.append(a , [[11,22,33,44], [0,0,0,0]] , axis = 1)

#df1 = pd.DataFrame(a)
#a1

a_tranpose = np.transpose(a)
a_tranpose

d2 = pd.DataFrame(a_tranpose)
d2
# Out:
#    0  1
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4

# %%
d1 = pd.DataFrame(a)
d1
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  1  2  3  4

# %% [markdown]
# **Normalising** or applying feature engineering on big mart dataset

# %%
df1 = df.filter(['Item_Weight' , 'Item_MRP'])
from sklearn.preprocessing import MinMaxScaler

# %%
norm_factor_df = MinMaxScaler().fit(df1)

# %%
print(type(norm_factor_df))
print(norm_factor_df)
# Out:
# <class 'sklearn.preprocessing._data.MinMaxScaler'>
# MinMaxScaler()

# %%
norm_arr = norm_factor_df.transform(df1)
print(type(norm_arr))
# Out:
# <class 'numpy.ndarray'>

# %%
norm_arr
# Out:
# array([[0.28252456, 0.92750715],
#        [0.08127419, 0.0720684 ],
#        [0.77076511, 0.46828841],
#        ...,
#        [0.35992855, 0.22849221],
#        [0.15808276, 0.30493925],
#        [0.61000298, 0.18750976]])

# %%
df2 = pd.DataFrame( norm_arr , columns = ['Item_Weight' , 'Item_MRP'])

# %%
df2['SNo'] = np.arange(len(df))
df2
# Out:
#       Item_Weight  Item_MRP   SNo
# 0        0.282525  0.927507     0
# 1        0.081274  0.072068     1
# 2        0.770765  0.468288     2
# 3        0.871986  0.640093     3
# 4        0.260494  0.095805     4
# ...           ...       ...   ...
# 8518     0.137541  0.777729  8518
# 8519     0.227746  0.326263  8519
# 8520     0.359929  0.228492  8520
# 8521     0.158083  0.304939  8521
# 8522     0.610003  0.187510  8522
#
# [8523 rows x 3 columns]
