# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'tour': np.repeat(np.arange(1,11), 30),
                   'experience': np.random.normal(loc=7, scale=1, size=300)})

# We use np.random to choose from an array(numpy). But we use x.sample(2) to choose from a pandas data frame
clusters = np.random.choice(np.arange(1,11) , size = 4)

cluster_sample = df[df['tour'].isin(clusters)]

cluster_sample['tour'].value_counts()
# Out:
# 1    30
# 7    30
# 8    30
# 9    30
# Name: tour, dtype: int64

# %%
tour_data  = pd.DataFrame({ 'tour_id': np.repeat(np.arange(0,6) , 10) ,
                            'Ratings' : np.random.random_integers(0,10, size = 60)})

print("Mean of ratings are ", tour_data.Ratings.mean())
tour_data.head(10)
# Out:
# Mean of ratings are  5.233333333333333
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10720\1274093501.py:2: DeprecationWarning: This function is deprecated. Please call randint(0, 10 + 1) instead
#   'Ratings' : np.random.random_integers(0,10, size = 60)})
#    tour_id  Ratings
# 0        0        3
# 1        0        8
# 2        0        8
# 3        0        7
# 4        0        0
# 5        0        3
# 6        0        8
# 7        0        7
# 8        0        7
# 9        0       10

# %%
np.repeat([1,2,3] ,3)
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 3, 3])

# %%
df = pd.DataFrame({'tour': np.repeat(np.arange(1,11), 30),
                   'experience': np.random.normal(loc=7, scale=1, size=300)})

# We use np.random to choose from an array(numpy). But we use x.sample(2) to choose from a pandas data frame


clusters = np.random.choice(df.tour.unique(), size = 4)



cluster_sample = df[df['tour'].isin(clusters)]

cluster_sample.tour.value_counts()
# Out:
# 2    30
# 5    30
# 6    30
# 9    30
# Name: tour, dtype: int64

# %%
data  = pd.read_csv("C:/Users/Lenovo/Desktop/startup_funding.csv")

data.iloc[ : : 5]
# Out:
#       Sr No Date dd/mm/yyyy  Startup Name  Industry Vertical  \
# 0         1      09/01/2020        BYJU’S             E-Tech
# 5         6      13/01/2020         Pando          Logistics
# 10       11      13/12/2019        Rivigo         Technology
# 15       16      11/12/2019    Rein Games             Gaming
# 20       21      17/11/2019  Burger Singh  Food and Beverage
# ...     ...             ...           ...                ...
# 3020   3021      19/01/2015        Enabli                NaN
# 3025   3026      21/01/2015   Simplilearn                NaN
# 3030   3031      22/01/2015     Freshmonk                NaN
# 3035   3036      24/01/2015      Impartus                NaN
# 3040   3041      29/01/2015      Graphene                NaN
#
#                                    SubVertical City  Location  \
# 0                                   E-learning      Bengaluru
# 5     Open-market, freight management platform        Chennai
# ...
